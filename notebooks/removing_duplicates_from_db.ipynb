# %%
import sys
sys.path.insert(0,'..')
from pg_connection import pg_connection, sql_types
import pandas as pd

# %%
conn = pg_connection(database='ipo_monitoring')

# %% [markdown]
# ## Get all tables from database

# %%
tables_query = """SELECT table_catalog, table_schema, table_name
FROM INFORMATION_SCHEMA.TABLES
WHERE TABLE_SCHEMA IN ('public')"""

df_tables = pd.read_sql_query(tables_query, conn)
tables = df_tables['table_name'].unique().tolist()

# %% [markdown]
# ## Finding tables with duplicates

# %%
dupe_tables = []
for table in tables:
    df_temp = pd.read_sql_table(table, conn)
    try:
        if len(df_temp.loc[df_temp.duplicated()]) > 0:
            dupe_tables.append(table)
    except Exception as e:
        print(f"error for {table} - {e}")
# Out:
# ref_sources - unhashable type: 'dict'

# %%
dupe_tables
# Out:
# ['source_shanghai_raw',
#  'source_east_money_raw',
#  'source_asx_raw',
#  'source_tkipo_raw',
#  'source_ipohub_raw',
#  'source_shanghai',
#  'source_east_money',
#  'source_tmx_raw']

# %% [markdown]
# Now that I have the tables with duplicates, I will read the tables again, drop duplicates and write them back to SQL. However, I have to be careful that the data types don't change.

# %% [markdown]
# ### source_shanghai_raw

# %%
source_shanghai_raw = pd.read_sql_table('source_shanghai_raw', conn)
print(len(source_shanghai_raw))

source_shanghai_raw.drop_duplicates(inplace=True)
num_cols = len(source_shanghai_raw.columns)
source_shanghai_raw.dropna(how='all', thresh=(num_cols-3))

print(len(source_shanghai_raw))
source_shanghai_raw.head()
# Out:
# 15565
# 14
#               time_added time_removed new_share_name subscription_date  \
# 0    2022-06-22 20:50:00          NaT           None              None
# 5183 2022-06-22 20:50:00          NaT     2022-05-26            136.66
# 5184 2022-06-22 20:50:00          NaT     2022-06-22             41.27
# 5185 2022-06-22 20:50:00          NaT     2022-05-18             15.37
# 5186 2022-06-22 20:50:00          NaT     2022-06-21             14.62
#
#                    price initial_shares_total_shares deal_size  \
# 0                     --                        None      None
# 5183      2666.672666.67                 364427.1222     127.9
# 5184  2240.08282240.0828                        None      None
# 5185          1124311243                   172804.91         0
# 5186          1200012000                        None      None
#
#              pe_ratio online_and_offline_circulation online_purchase_limit  \
# 0                  --                           None                  None
# 5183  930.951578.4026                           0.65            0.04404097
# 5184   725.81155.7653                            0.5            0.03347961
# 5185   2361.055509.05                           1.55             0.0483009
# 5186        108001200                            3.6            0.06706069
#
#      success_rate announcement_of_winning_results
# 0            None                            None
# 5183   2022-05-30                      2022-06-08
# 5184   2022-06-24                            None
# 5185   2022-05-20                      2022-05-27
# 5186   2022-06-23                            None

# %%
source_shanghai_raw.to_sql('source_shanghai_raw', conn, if_exists='replace', index=False)

# %% [markdown]
# ### source_east_money_raw

# %%
source_east_money_raw = pd.read_sql_table('source_east_money_raw', conn)
print(len(source_east_money_raw))

source_east_money_raw.drop_duplicates(inplace=True)
num_cols = len(source_east_money_raw.columns)
source_east_money_raw.dropna(how='all', thresh=(num_cols-3))

print(len(source_east_money_raw))
source_east_money_raw.head()
# Out:
# 5899
# 5852
#    ticker company_name relevant_information  subscription_code  \
# 0    1266         宏英智能             详细 研报 股吧               1266
# 1  688223         晶科能源             详细 研报 股吧             787223
# 2  301116         益客食品             详细 研报 股吧             301116
# 3  603122         合富中国             详细 研报 股吧             732122
# 4  688176         亚虹医药             详细 研报 股吧             787176
#
#   shares_offered_total shares_offered_online  \
# 0                    -                   734
# 1               200000                 42000
# 2                 4490                  1626
# 3                 9951                  8956
# 4                11000                  3157
#
#   top_grid_purchase_match_mkt_value subscription_limit  price latest_price  \
# 0                              7.00               0.70      -            -
# 1                            280.00              28.00   5.00        10.32
# 2                              7.50               0.75  11.40        23.09
# 3                             39.00               3.90   4.19            -
# 4                             20.50               2.05  22.98        15.47
#
#    ... pe_ratio_industry success_rate number_of_inquiries  \
# 0  ...                 -            -                   -
# 1  ...              48.8     0.149621             1275.26
# 2  ...             29.93     0.020086             4775.02
# 3  ...             18.74     0.044919             3255.63
# 4  ...             38.63     0.035244             2875.44
#
#   number_of_allotments market_segment percent_change change_from_ipo_price  \
# 0                    -            待上市              -                     -
# 1                11283              -         104.00                  2600
# 2                 9147              -         203.60                 11605
# 3                12786            待上市              -                     -
# 4                 9423              -         -19.06                 -2190
#
#   document_link          time_added        time_removed
# 0          None 2022-02-08 16:50:00 2022-02-08 21:50:00
# 1          None 2022-02-08 16:50:00 2022-02-09 01:50:00
# 2          None 2022-02-08 16:50:00 2022-02-09 01:50:00
# 3          None 2022-02-08 16:50:00 2022-02-09 01:50:00
# 4          None 2022-02-08 16:50:00 2022-02-09 01:50:00
#
# [5 rows x 26 columns]

# %%
source_east_money_raw.to_sql('source_east_money_raw', conn, if_exists='replace', index=False)

# %% [markdown]
# ### source_asx_raw

# %%
source_asx_raw = pd.read_sql_table('source_asx_raw', conn)
print(len(source_asx_raw))

source_asx_raw.drop_duplicates(inplace=True)
num_cols = len(source_asx_raw.columns)
source_asx_raw.dropna(how='all', thresh=(num_cols-3))

print(len(source_asx_raw))
source_asx_raw.head()
# Out:
# 910
# 826
#            time_added time_removed  \
# 0 2021-03-16 22:26:00          NaT
# 1 2021-03-16 22:26:00          NaT
# 2 2021-03-18 10:01:00          NaT
# 3 2021-03-18 10:01:00          NaT
# 4 2021-03-18 10:01:00          NaT
#
#                                         listing_info  \
# 0                              Metal Tiger PLC - TBA
# 1                        Juno Minerals Limited - TBA
# 2               Peregrine Gold Ltd - 22 March 2021 #
# 3  Tulla Resources Plc - \t18 March 2021 12:00PM  ##
# 4  Bastion Minerals Limited - 16 March 2021 11:00...
#
#                company_name   ipo_date                   exchange
# 0           Metal Tiger PLC        NaT  Australian Stock Exchange
# 1     Juno Minerals Limited        NaT  Australian Stock Exchange
# 2        Peregrine Gold Ltd 2021-03-22  Australian Stock Exchange
# 3       Tulla Resources Plc 2021-03-18  Australian Stock Exchange
# 4  Bastion Minerals Limited 2021-03-16  Australian Stock Exchange

# %%
source_asx_raw.to_sql('source_asx_raw', conn, if_exists='replace', index=False)

# %% [markdown]
# ### source_tkipo_raw

# %%
source_tkipo_raw = pd.read_sql_table('source_tkipo_raw', conn)
print(len(source_tkipo_raw))

source_tkipo_raw.drop_duplicates(inplace=True)
num_cols = len(source_tkipo_raw.columns)
source_tkipo_raw.dropna(how='all', thresh=(num_cols-3))

print(len(source_tkipo_raw))
source_tkipo_raw.head()
# Out:
# 279722
# 792
#            time_added time_removed                         company_name  \
# 0 2021-03-16 22:26:00          NaT                Broad-Minded Co.,Ltd.
# 1 2021-03-16 22:26:00          NaT  Terminalcare Support Institute Inc．
# 2 2021-03-16 22:26:00          NaT                     e-LogiT co.,ltd.
# 3 2021-03-16 22:26:00          NaT                          G-NEXT Inc.
# 4 2021-03-16 22:26:00          NaT                          i-plug,Inc.
#
#     ipo_date  ticker   shares_outstanding  price_range   price  \
# 0 2021-03-26    7343  900,000 - 1,035,000      710-810     NaN
# 1 2021-03-19    7362    400,000 - 460,000  1,700-2,000  2000.0
# 2 2021-03-26    9327  915,600 - 1,048,800  1,400-1,500     NaN
# 3 2021-03-25    4179    556,500 - 639,900  1,130-1,230     NaN
# 4 2021-03-18    4177    511,600 - 588,300  2,470-2,620  2620.0
#
#   bookbuilding_period opening_price percent_change underwriters  \
# 0       03/10 - 03/16          None           None       Mizuho
# 1       03/03 - 03/09          None           None       Nomura
# 2       03/10 - 03/16          None           None    Ichiyoshi
# 3       03/10 - 03/16          None           None   SMBC Nikko
# 4       03/03 - 03/09          None           None        Daiwa
#
#   price_range_expected_date price_expected_date                    exchange
# 0                      None              17-Mar  Japan Stock Exchange - MTH
# 1                      None                None  Japan Stock Exchange - MTH
# 2                      None              17-Mar  Japan Stock Exchange - JQS
# 3                      None              17-Mar  Japan Stock Exchange - MTH
# 4                      None                None  Japan Stock Exchange - MTH

# %%
source_tkipo_raw.to_sql('source_tkipo_raw', conn, if_exists='replace', index=False)

# %% [markdown]
# ### source_ipohub_raw

# %%
source_ipohub_raw = pd.read_sql_table('source_ipohub_raw', conn)
print(len(source_ipohub_raw))

source_ipohub_raw.drop_duplicates(inplace=True)
num_cols = len(source_ipohub_raw.columns)
source_ipohub_raw.dropna(how='all', thresh=(num_cols-3))

print(len(source_ipohub_raw))
source_ipohub_raw.head()
# Out:
# 5799408
# 379
#                        time_added time_removed        company_name  \
# 0      2021-11-30 15:08:29.729944          NaT     Vici iGaming AB
# 1      2021-11-30 15:08:29.729944          NaT      Dala Energi AB
# 96463  2021-11-30 15:08:29.729944          NaT         Paydrive AB
# 96689  2021-11-30 15:08:29.729944          NaT  Eco-Oil Sverige AB
# 111841 2021-11-30 15:08:29.729944          NaT  Titania Holding AB
#
#                                exchange listing_type   subscription_period  \
# 0       Spotlight Stock Market (Sweden)      Listing                  None
# 1        Nasdaq First North GM (Sweden)      Listing                  None
# 96463           NGM Nordic SME (Sweden)          IPO  23 Nov - 07 Dec 2021
# 96689           NGM Nordic SME (Sweden)      Listing                  None
# 111841   Nasdaq First North GM (Sweden)          IPO  30 Nov - 09 Dec 2021
#
#         price market_cap    deal_size  status ipo_date price_range currency
# 0         NaN       None         None    None      NaT        None     None
# 1         NaN       None         None    None      NaT        None     None
# 96463    17.1   100M SEK  20M-23M SEK  Active      NaT        None      SEK
# 96689     NaN       None         None    None      NaT        None     None
# 111841   20.0     1B SEK     430M SEK  Active      NaT        None      SEK

# %%
source_ipohub_raw.to_sql('source_ipohub_raw', conn, if_exists='replace', index=False)

# %% [markdown]
# ### source_shanghai

# %%
source_shanghai = pd.read_sql_table('source_ipohub_raw', conn)
print(len(source_shanghai))

source_shanghai.drop_duplicates(inplace=True)
num_cols = len(source_shanghai.columns)
source_shanghai.dropna(how='all', thresh=(num_cols-3))

print(len(source_shanghai))
source_shanghai.head()
# Out:
# 5799408
# 379
#                        time_added time_removed        company_name  \
# 0      2021-11-30 15:08:29.729944          NaT     Vici iGaming AB
# 1      2021-11-30 15:08:29.729944          NaT      Dala Energi AB
# 96463  2021-11-30 15:08:29.729944          NaT         Paydrive AB
# 96689  2021-11-30 15:08:29.729944          NaT  Eco-Oil Sverige AB
# 111841 2021-11-30 15:08:29.729944          NaT  Titania Holding AB
#
#                                exchange listing_type   subscription_period  \
# 0       Spotlight Stock Market (Sweden)      Listing                  None
# 1        Nasdaq First North GM (Sweden)      Listing                  None
# 96463           NGM Nordic SME (Sweden)          IPO  23 Nov - 07 Dec 2021
# 96689           NGM Nordic SME (Sweden)      Listing                  None
# 111841   Nasdaq First North GM (Sweden)          IPO  30 Nov - 09 Dec 2021
#
#         price market_cap    deal_size  status ipo_date price_range currency
# 0         NaN       None         None    None      NaT        None     None
# 1         NaN       None         None    None      NaT        None     None
# 96463    17.1   100M SEK  20M-23M SEK  Active      NaT        None      SEK
# 96689     NaN       None         None    None      NaT        None     None
# 111841   20.0     1B SEK     430M SEK  Active      NaT        None      SEK

# %%
source_shanghai.to_sql('source_shanghai', conn, if_exists='replace', index=False)

# %% [markdown]
# ### source_tmx_raw

# %%
source_tmx_raw = pd.read_sql_table('source_tmx_raw', conn)
print(len(source_tmx_raw))

source_tmx_raw.drop_duplicates(inplace=True)
num_cols = len(source_tmx_raw.columns)
source_tmx_raw.dropna(how='all', thresh=(num_cols-3))

print(len(source_tmx_raw))
source_tmx_raw.head()
# Out:
# 12416
# 12108
#    identification entry_date cusip   change_type  \
# 0        20210596 2021-06-10  None  Supplemental
# 1        20210593 2021-06-10  None   New Listing
# 2        20210588 2021-06-09  None   New Listing
# 3        20210559 2021-06-01  None        Delist
# 4        20210598 2021-06-11  None   New Listing
#
#                               company_name security_description  \
# 0                    Novo Resources Corp.              Warrants
# 1                         MediaValet Inc.         Common Shares
# 2                  Blackline Safety Corp.         Common Shares
# 3  Global Telecom & Utilities Income Fund                 Units
# 4      Dynamic Active Emerging Markets ETF                Units
#
#   changed_cusip_new changed_company_name_new changed_security_description_new  \
# 0              None                     None                             None
# 1              None                     None                             None
# 2              None                     None                             None
# 3              None                     None                             None
# 4              None                     None                             None
#
#   list_symbol delist_symbol split/consolidation_factor effective_date  \
# 0    NVO.WT.A          None                       None     2021-06-14
# 1         MVP          None                       None     2021-06-14
# 2         BLN          None                       None     2021-06-11
# 3        None        HGI.UN                       None     2021-06-15
# 4        DXEM          None                       None     2021-06-15
#
#                               details modification_date exchange  \
# 0                                None               NaT      TSX
# 1  transfer from TSX Venture Exchange               NaT      TSX
# 2  transfer from TSX Venture Exchange               NaT      TSX
# 3                following redemption               NaT      TSX
# 4             Initial Public Offering               NaT      TSX
#
#                                 file                 time_added  \
# 0  20210614TSXListingsChanges_NC.txt 2021-07-13 17:48:03.245725
# 1  20210614TSXListingsChanges_NC.txt 2021-07-13 17:48:03.245725
# 2  20210614TSXListingsChanges_NC.txt 2021-07-13 17:48:03.245725
# 3  20210614TSXListingsChanges_NC.txt 2021-07-13 17:48:03.245725
# 4  20210614TSXListingsChanges_NC.txt 2021-07-13 17:48:03.245725
#
#          time_removed
# 0 2021-07-20 16:33:00
# 1 2021-07-20 16:33:00
# 2 2021-07-20 16:33:00
# 3 2021-07-20 16:33:00
# 4 2021-07-20 16:33:00

# %%
source_tmx_raw.to_sql('source_tmx_raw', conn, if_exists='replace', index=False)

# %%
conn.close()
